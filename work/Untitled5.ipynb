# %%
import pandas

# %%
import numpy

# %%
mcdonaldMenu = pd.read_csv("../work/menu.csv")
mcdonaldMenu
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
starbucksMenu = pd.read_csv("../work/starbucks-menu-nutrition-drinks.csv")
starbucksMenu
# Out:
#                                             Unnamed: 0 Calories Fat (g)  \
# 0             Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                     Ombré Pink Drink        -       -
# 2                                           Pink Drink        -       -
# 3       Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
# ..                                                 ...      ...     ...
# 172                                 Chocolate Smoothie      320       5
# 173                                Strawberry Smoothie      300       2
# 174                                         Ginger Ale        -       -
# 175                                          Lemon Ale        -       -
# 176                                  Orange Cream Soda        -       -
#
#     Carb. (g) Fiber (g) Protein Sodium
# 0          11         0       0     10
# ...

# %%
d = {"mcdonaldMenu":["Category","Item","Serving Size","Calories"]}
df = pandas.DataFrame(d)
df
# Out:
#    mcdonaldMenu
# 0      Category
# 1          Item
# 2  Serving Size
# 3      Calories

# %%
def func_nb():
    data = pandas.read_csv('menu.csv')
    df = DataFrame(data)
    df['Tag'] = df['Tag'].map(lambda x: re.sub(r'\W+', '_', x))
    return df
df = func_nb()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d17deee94335> in <module>
#       4     df['Tag'] = df['Tag'].map(lambda x: re.sub(r'\W+', '_', x))
#       5     return df
# ----> 6 df = func_nb()
#       7
#       8
#
# <ipython-input-16-d17deee94335> in func_nb()
#       1 def func_nb():
#       2     data = pandas.read_csv('menu.csv')
# ----> 3     df = DataFrame(data)
#       4     df['Tag'] = df['Tag'].map(lambda x: re.sub(r'\W+', '_', x))
#       5     return df
#
# NameError: name 'DataFrame' is not defined

# %%
df["calories"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /hpc/applications/anaconda/3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'calories'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-2a4c5e702efb> in <module>
# ----> 1 df["calories"]
#
# ...

# %%
cols=["Category","Item","Serving Size","Calories"]
data = pd.DataFrame(columns=cols)

# %%
data
# Out:
# Empty DataFrame
# Columns: [Category, Item, Serving Size, Calories]
# Index: []

# %%
data.groupby(by='Calories').count()
# Out:
# Empty DataFrame
# Columns: [Category, Item, Serving Size]
# Index: []

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
